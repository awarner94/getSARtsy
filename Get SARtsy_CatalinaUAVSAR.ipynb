# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import os
from osgeo import gdal
import geopandas as gpd
import rasterio as rio
from rasterio.plot import show

import re
import getpass
import codecs
import netrc
import glob
import zipfile

# %%
fp = r'ChanIs_30104_22054_013_221130_L090_CX_01_pauli.tif'
img = rio.open(fp)
show(img)
# Out:
# <AxesSubplot:>

# %%
dataset = rio.open(fp)
print(dataset.count)
print(dataset.height, dataset.width)
print(dataset.crs)
# Out:
# 3
# 17276 30526
# GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST]]
# ERROR 1: PROJ: internal_proj_identify: /opt/anaconda3/share/proj/proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.
